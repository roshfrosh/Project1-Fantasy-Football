# %%
import http.client
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import sys

key = "h53gmfp5pf94b9qwzavnfhwc"

# %%
# File to Load 
team_data_to_load = "Team_List.csv"
players_2018_data_to_load = "Offense_Player_List_2018.csv"

# Read Team and Player Data File and store into Pandas Data Frames
team_df = pd.read_csv(team_data_to_load)
players_2018_data = pd.read_csv(players_2018_data_to_load)

# %%
#Rushing
#params to initiate loop through teams
year_list = ["2012", "2013", "2014", "2015", "2016", "2017", "2018"]
offensive_pos = ["TE", "WR", "RB", "QB", "FB", "K"]
master_player_list = players_2018_data["Player ID"].tolist()
team_list = team_df["Team ID"].tolist()
teamname_list = team_df["Name"].tolist()


pid_df = []
season_df = []
punt_attempts_df = []
punt_avg_hang_time_df =[]
punt_avg_net_yards_df =[]
punt_avg_yard_df =[]
punt_blocked_df =[]
punt_hang_time_df =[]
punt_inside_20_df =[]
punt_longest_df =[]
punt_net_yards_df =[]
punt_return_yards_df =[]
punt_touchbacks_df =[]
punt_yards_df =[]



for a in range(len(year_list)):
    yr = year_list[a]
    for i in range (len(team_list)):
        print (str(i) + "||" + yr)
        url7 = "https://api.sportradar.us/nfl/official/trial/v5/en/seasons/" + yr + "/REG/teams/" + team_list[i] + "/statistics.json?api_key=" + key
        time.sleep(1)
        JSONContent7 = requests.get(url7).json()
        player_ct = len(JSONContent7["players"])
        for j in range (0, player_ct):
            pid = JSONContent7["players"][j]["id"]
            if pid in master_player_list:
                try:
                    punt_attempts = JSONContent7["players"][j]["punts"]["attempts"] 
                    punt_avg_hang_time =JSONContent7["players"][j]["punts"]["avg_hang_time"] 
                    punt_avg_net_yards =JSONContent7["players"][j]["punts"]["avg_net_yards"] 
                    punt_avg_yard =JSONContent7["players"][j]["punts"]["avg_yards"] 
                    punt_blocked =JSONContent7["players"][j]["punts"]["blocked"] 
                    punt_hang_time =JSONContent7["players"][j]["punts"]["hang_time"] 
                    punt_inside_20 =JSONContent7["players"][j]["punts"]["inside_20"]  
                    punt_longest =JSONContent7["players"][j]["punts"]["longest"] 
                    punt_net_yards =JSONContent7["players"][j]["punts"]["net_yards"] 
                    punt_return_yards =JSONContent7["players"][j]["punts"]["return_yards"] 
                    punt_touchbacks =JSONContent7["players"][j]["punts"]["touchbacks"] 
                    punt_yards =JSONContent7["players"][j]["punts"]["yards"] 
                    season_df.append(yr)
                    pid_df.append(pid)
                    punt_attempts_df.append(punt_attempts)
                    punt_avg_hang_time_df.append(punt_avg_hang_time)
                    punt_avg_net_yards_df.append(punt_avg_net_yards)
                    punt_avg_yard_df.append(punt_avg_yard)
                    punt_blocked_df.append(punt_blocked)
                    punt_hang_time_df.append(punt_hang_time)
                    punt_inside_20_df.append(punt_inside_20)
                    punt_longest_df.append(punt_longest)
                    punt_net_yards_df.append(punt_net_yards)
                    punt_return_yards_df.append(punt_return_yards)
                    punt_touchbacks_df.append(punt_touchbacks)
                    punt_yards_df.append(punt_yards)
                    print(pid)
                except:
                   print(sys.exc_info())  
                   continue 


data5 = {"Player Season": season_df,
        "Player ID": pid_df,
        "Punt Attempts":punt_attempts_df,
        "Punt Avg Hang Time":punt_avg_hang_time_df,
        "Punt Avg Net Yards":punt_avg_net_yards_df,
        "Punt Avg Yards":punt_avg_yard_df,
        "Punt Blocked":punt_blocked_df,
        "Punt Hangtime":punt_hang_time_df,
        "Punt Inside 20":punt_inside_20_df,
        "Punt Longest":punt_longest_df,
        "Punt Net Yards":punt_net_yards_df,
        "Punt Return Yards":punt_return_yards_df,
        "Punt Touchbacks":punt_touchbacks_df,
        "Punt Yards":punt_yards_df

      }

player_punt_df = pd.DataFrame(data5) 
player_punt_df.head()
# Out:
# 0||2012
# (<class 'KeyError'>, KeyError('punts'), <traceback object at 0x000001D23CFD4F88>)
# (<class 'KeyError'>, KeyError('punts'), <traceback object at 0x000001D23CFD4F88>)
# (<class 'KeyError'>, KeyError('punts'), <traceback object at 0x000001D23CFD4F88>)
# 1||2012
# (<class 'KeyError'>, KeyError('punts'), <traceback object at 0x000001D23A1C7AC8>)
# (<class 'KeyError'>, KeyError('punts'), <traceback object at 0x000001D23A1C7AC8>)
# (<class 'KeyError'>, KeyError('punts'), <traceback object at 0x000001D23A1C7AC8>)
# (<class 'KeyError'>, KeyError('punts'), <traceback object at 0x000001D23A1C7AC8>)
# 2||2012
# (<class 'KeyError'>, KeyError('punts'), <traceback object at 0x000001D23D44FF88>)
# (<class 'KeyError'>, KeyError('punts'), <traceback object at 0x000001D23D44FF88>)
# (<class 'KeyError'>, KeyError('punts'), <traceback object at 0x000001D23D44FF88>)
# (<class 'KeyError'>, KeyError('punts'), <traceback object at 0x000001D23D44FF88>)
# 3||2012
# ...

# %%
player_punt_df.to_csv(r'Offense_Player_Punt_Stats_2012_to_2018.csv')
