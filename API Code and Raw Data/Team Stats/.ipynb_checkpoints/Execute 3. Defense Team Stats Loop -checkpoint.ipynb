# %%
import http.client
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import sys

key = "6h56aqdvvjf4s6r4fz9d3tht"

# %%
# File to Load 
team_data_to_load = "Resources/Input/Team_List.csv"

# Read Team and Player Data File and store into Pandas Data Frames
team_df = pd.read_csv(team_data_to_load)

# %%
#Receiving Data
#params to initiate loop through teams
year_list = ["2012", "2013", "2014", "2015", "2016", "2017", "2018"]
team_list = team_df["Team ID"].tolist()


#lists
team_id_df = []
season_df = []
key_df = []
def_assists_df = [] 
def_blitzes_df = []  
def_comb_df = []  
def_def_comps_df =[] 
def_def_targets_df =[] 
def_forced_fumbles_df =[] 
def_fumble_recoveries_df = []   
def_hurries_df =[]  
def_interceptions_df =[]   
def_knockdowns_df =[]
def_misc_assists_df =[] 
def_misc_forced_fumbles_df =[] 
def_misc_fumble_recoveries_df =[]   
def_misc_tackles_df =[]
def_miss_tackles_df =[] 
def_passes_defended_df =[] 
def_qb_hits_df =[]  
def_sack_yds_df =[] 
def_sacks_df =[]  
def_safeties_df =[] 
def_sp_assists_df =[]  
def_sp_blocks_df =[]  
def_sp_forced_fumbles_df =[] 
def_sp_fumble_recoveries_df =[]  
def_sp_tackles_df =[]
def_tackles_df =[]  
def_tloss_df =[] 
def_tloss_yds_df =[] 




#params to process player descriptive data
for a in range(len(year_list)):
    yr = year_list[a]
    for i in range (len(team_list)):
        print (str(i) + "||" + yr)
        url = "https://api.sportradar.us/nfl/official/trial/v5/en/seasons/" + yr + "/REG/teams/" + team_list[i] + "/statistics.json?api_key=" + key
        time.sleep(2)
        JSONContent = requests.get(url).json()
        try: 
            def_assists = JSONContent["record"]["defense"]["assists"] 
            def_blitzes = JSONContent["record"]["defense"]["blitzes"]  
            def_comb = JSONContent["record"]["defense"]["combined"]  
            def_def_comps =JSONContent["record"]["defense"]["def_comps"]  
            def_def_targets =JSONContent["record"]["defense"]["def_targets"]  
            def_forced_fumbles =JSONContent["record"]["defense"]["forced_fumbles"]  
            def_fumble_recoveries = JSONContent["record"]["defense"]["fumble_recoveries"]  
            def_hurries =JSONContent["record"]["defense"]["hurries"]   
            def_interceptions =JSONContent["record"]["defense"]["interceptions"]  
            def_knockdowns =JSONContent["record"]["defense"]["knockdowns"]  
            def_misc_assists =JSONContent["record"]["defense"]["misc_assists"]  
            def_misc_forced_fumbles =JSONContent["record"]["defense"]["misc_forced_fumbles"]  
            def_misc_fumble_recoveries =JSONContent["record"]["defense"]["misc_fumble_recoveries"]  
            def_misc_tackles =JSONContent["record"]["defense"]["misc_tackles"]  
            def_miss_tackles =JSONContent["record"]["defense"]["missed_tackles"]  
            def_passes_defended =JSONContent["record"]["defense"]["passes_defended"]  
            def_qb_hits =JSONContent["record"]["defense"]["qb_hits"]  
            def_sack_yds =JSONContent["record"]["defense"]["sack_yards"]  
            def_sacks =JSONContent["record"]["defense"]["sacks"]  
            def_safeties =JSONContent["record"]["defense"]["safeties"]  
            def_sp_assists =JSONContent["record"]["defense"]["sp_assists"]  
            def_sp_blocks =JSONContent["record"]["defense"]["sp_blocks"]  
            def_sp_forced_fumbles =JSONContent["record"]["defense"]["sp_forced_fumbles"]  
            def_sp_fumble_recoveries =JSONContent["record"]["defense"]["sp_fumble_recoveries"]  
            def_sp_tackles =JSONContent["record"]["defense"]["sp_tackles"]  
            def_tackles =JSONContent["record"]["defense"]["tackles"]  
            def_tloss =JSONContent["record"]["defense"]["tloss"]  
            def_tloss_yds =JSONContent["record"]["defense"]["tloss_yards"]
            season_df.append(yr)
            team_id_df.append(team_list[i])
            key_df.append(team_list[i]+yr)
            def_assists_df.append(def_assists) 
            def_blitzes_df.append(def_blitzes)
            def_comb_df.append(def_comb) 
            def_def_comps_df.append(def_def_comps)
            def_def_targets_df.append(def_def_targets) 
            def_forced_fumbles_df.append(def_forced_fumbles) 
            def_fumble_recoveries_df.append(def_fumble_recoveries)   
            def_hurries_df.append(def_hurries) 
            def_interceptions_df.append(def_interceptions)   
            def_knockdowns_df.append(def_knockdowns)
            def_misc_assists_df.append(def_misc_assists) 
            def_misc_forced_fumbles_df.append(def_misc_forced_fumbles)
            def_misc_fumble_recoveries_df.append(def_misc_fumble_recoveries)   
            def_misc_tackles_df.append(def_misc_tackles)
            def_miss_tackles_df.append(def_miss_tackles)
            def_passes_defended_df.append(def_passes_defended)
            def_qb_hits_df.append(def_qb_hits)  
            def_sack_yds_df.append(def_sack_yds)
            def_sacks_df.append(def_sacks)  
            def_safeties_df.append(def_safeties) 
            def_sp_assists_df.append(def_sp_assists)  
            def_sp_blocks_df.append(def_sp_blocks)  
            def_sp_forced_fumbles_df.append(def_sp_forced_fumbles) 
            def_sp_fumble_recoveries_df.append(def_sp_fumble_recoveries) 
            def_sp_tackles_df.append(def_sp_tackles)
            def_tackles_df.append(def_tackles) 
            def_tloss_df.append(def_tloss)
            def_tloss_yds_df.append(def_tloss_yds)
            print("Team: "+team_list[i])
        except:
            print(sys.exc_info())  
            continue 

data = {"Season": season_df, 
        "Team ID": team_id_df, 
        "TKey": key_df, 
        "Def Assisted Tackles": def_assists_df,
        "Def Blitzes": def_blitzes_df,
        "Def Combined Tackles": def_comb_df, 
        "Def Defensive Completions": def_def_comps_df,
        "Def Defensive Targets": def_def_targets_df,
        "Def Forced Fumbles":def_forced_fumbles_df, 
        "Def Fumble Recoveries":def_fumble_recoveries_df, 
        "Def Hurries":def_hurries_df, 
        "Def Interceptions":def_interceptions_df, 
        "Def Knockdowns":def_knockdowns_df,
        "Def Misc Assists":def_misc_assists_df,
        "Def Misc Forced Fumbles":def_misc_forced_fumbles_df,
        "Def Misc Fumble Recoveries":def_misc_fumble_recoveries_df,  
        "Def Misc Tackles":def_misc_tackles_df,
        "Def Missed Tackles":def_miss_tackles_df,
        "Def Passes Defended":def_passes_defended_df,
        "Def QB Hits":def_qb_hits_df,
        "Def Sack Yards":def_sack_yds_df,
        "Def Sacks":def_sacks_df,
        "Def Safeties":def_safeties_df,
        "Def Special Team Assists":def_sp_assists_df,
        "Def Special Team Bocks":def_sp_blocks_df,
        "Def Special Team Forced Fumbles":def_sp_forced_fumbles_df,
        "Def Special Team Fumble Recoveries":def_sp_fumble_recoveries_df,
        "Def Special Team Tackles":def_sp_tackles_df,
        "Def Tackles":def_tackles_df,
        "Def Tackles for Loss":def_tloss_df,
        "Def Tackles for Loss Yards":def_tloss_yds_df
       }

df = pd.DataFrame(data) 
df.head()
# Out:
# 0||2012
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD2CC988>)
# 1||2012
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD3D4408>)
# 2||2012
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD280D88>)
# 3||2012
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD4036C8>)
# 4||2012
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD4101C8>)
# 5||2012
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD66AEC8>)
# 6||2012
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD403EC8>)
# 7||2012
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD40F548>)
# 8||2012
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD683EC8>)
# 9||2012
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDA1172C8>)
# 10||2012
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDBB8EF88>)
# 11||2012
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDA32D588>)
# 12||2012
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD40D948>)
# 13||2012
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD40F548>)
# 14||2012
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD698988>)
# 15||2012
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD280E48>)
# 16||2012
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD402BC8>)
# 17||2012
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD412088>)
# 18||2012
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDA1172C8>)
# 19||2012
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD3D4648>)
# 20||2012
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD2CC988>)
# 21||2012
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD68F7C8>)
# 22||2012
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD40A648>)
# 23||2012
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD2184C8>)
# 24||2012
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD402BC8>)
# 25||2012
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD412088>)
# 26||2012
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD3BE9C8>)
# 27||2012
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDA1172C8>)
# 28||2012
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDA32D588>)
# 29||2012
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD40D3C8>)
# 30||2012
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD40F548>)
# 31||2012
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD3BE9C8>)
# 0||2013
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD40D3C8>)
# 1||2013
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD40A648>)
# 2||2013
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD2CC988>)
# 3||2013
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD40F548>)
# 4||2013
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD280D88>)
# 5||2013
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD2BF9C8>)
# 6||2013
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD40A648>)
# 7||2013
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD403EC8>)
# 8||2013
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD69A188>)
# 9||2013
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD2184C8>)
# 10||2013
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD698108>)
# 11||2013
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD40A648>)
# 12||2013
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDBB8EF88>)
# 13||2013
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDA32D588>)
# 14||2013
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD697DC8>)
# 15||2013
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD69A448>)
# 16||2013
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDA32D588>)
# 17||2013
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD40D3C8>)
# 18||2013
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD2CC988>)
# 19||2013
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD677A08>)
# 20||2013
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD40D3C8>)
# 21||2013
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDA32D588>)
# 22||2013
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD40A648>)
# 23||2013
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD402BC8>)
# 24||2013
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD2CC988>)
# 25||2013
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD2184C8>)
# 26||2013
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD4036C8>)
# 27||2013
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD4101C8>)
# 28||2013
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD402688>)
# 29||2013
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD66A208>)
# 30||2013
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD2CC988>)
# 31||2013
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD4101C8>)
# 0||2014
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD680708>)
# 1||2014
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD2CC988>)
# 2||2014
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD2184C8>)
# 3||2014
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD66A288>)
# 4||2014
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD2CC988>)
# 5||2014
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD66AF08>)
# 6||2014
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD40D3C8>)
# 7||2014
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD3D4648>)
# 8||2014
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD2184C8>)
# 9||2014
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD40D3C8>)
# 10||2014
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD403EC8>)
# 11||2014
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD419408>)
# 12||2014
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD402BC8>)
# 13||2014
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD2BF9C8>)
# 14||2014
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD3BE5C8>)
# 15||2014
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDBB8EF88>)
# 16||2014
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD2184C8>)
# 17||2014
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD3BEC88>)
# 18||2014
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD419348>)
# 19||2014
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD3D4648>)
# 20||2014
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD66B188>)
# 21||2014
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD697708>)
# 22||2014
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD66B708>)
# 23||2014
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD40A648>)
# 24||2014
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDBB8EF88>)
# 25||2014
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD2184C8>)
# 26||2014
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD40D948>)
# 27||2014
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD2CC988>)
# 28||2014
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD4101C8>)
# 29||2014
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD280E48>)
# 30||2014
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD2184C8>)
# 31||2014
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD3D4648>)
# 0||2015
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD694208>)
# 1||2015
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD4101C8>)
# 2||2015
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDA32D588>)
# 3||2015
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD40D3C8>)
# 4||2015
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD2CC988>)
# 5||2015
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD2BF9C8>)
# 6||2015
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD40F548>)
# 7||2015
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDA32D588>)
# 8||2015
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD402A88>)
# 9||2015
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD2184C8>)
# 10||2015
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD419F48>)
# 11||2015
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD40A648>)
# 12||2015
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDA1172C8>)
# 13||2015
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD40D3C8>)
# 14||2015
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD280D88>)
# 15||2015
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD4036C8>)
# 16||2015
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDA1172C8>)
# 17||2015
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDBB8EF88>)
# 18||2015
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD403EC8>)
# 19||2015
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD2BF9C8>)
# 20||2015
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD419BC8>)
# 21||2015
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD3BE5C8>)
# 22||2015
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD412088>)
# 23||2015
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD3D4648>)
# 24||2015
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDBB8EF88>)
# 25||2015
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD280D88>)
# 26||2015
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD40F548>)
# 27||2015
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD402A88>)
# 28||2015
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD2CC988>)
# 29||2015
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDBB8EF88>)
# 30||2015
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD40A648>)
# 31||2015
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDA1172C8>)
# 0||2016
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD2184C8>)
# 1||2016
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDA32D588>)
# 2||2016
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDA1172C8>)
# 3||2016
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD3BE5C8>)
# 4||2016
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDBB8EF88>)
# 5||2016
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD698908>)
# 6||2016
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD40D948>)
# 7||2016
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD2184C8>)
# 8||2016
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD403EC8>)
# 9||2016
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD40F548>)
# 10||2016
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDA1172C8>)
# 11||2016
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDA32D588>)
# 12||2016
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD2CC988>)
# 13||2016
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD3D4648>)
# 14||2016
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD40F548>)
# 15||2016
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDBB8EF88>)
# 16||2016
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD402688>)
# 17||2016
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD2BF9C8>)
# 18||2016
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD4036C8>)
# 19||2016
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD3BE9C8>)
# 20||2016
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD2184C8>)
# 21||2016
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD280D88>)
# 22||2016
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD695F08>)
# 23||2016
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD402688>)
# 24||2016
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD2CC988>)
# 25||2016
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD4101C8>)
# 26||2016
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDA1172C8>)
# 27||2016
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD3BEA48>)
# 28||2016
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDBB8EF88>)
# 29||2016
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDA32D588>)
# 30||2016
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD40F548>)
# 31||2016
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD402BC8>)
# 0||2017
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD40A648>)
# 1||2017
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD2BF9C8>)
# 2||2017
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD402BC8>)
# 3||2017
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD403EC8>)
# 4||2017
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD2184C8>)
# 5||2017
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD69D708>)
# 6||2017
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDA1172C8>)
# 7||2017
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD3D4648>)
# 8||2017
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD2BF9C8>)
# 9||2017
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDBB8EF88>)
# 10||2017
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD4101C8>)
# 11||2017
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDA32D588>)
# 12||2017
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD40F548>)
# 13||2017
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD40D3C8>)
# 14||2017
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD697F08>)
# 15||2017
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD412088>)
# 16||2017
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDBB8EF88>)
# 17||2017
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD674848>)
# 18||2017
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDA32D588>)
# 19||2017
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD2184C8>)
# 20||2017
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD2CC988>)
# 21||2017
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD2BF9C8>)
# 22||2017
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD4101C8>)
# 23||2017
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD3BE9C8>)
# 24||2017
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD412088>)
# 25||2017
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD3BEA48>)
# 26||2017
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD40F548>)
# 27||2017
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD40A648>)
# 28||2017
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDA32D588>)
# 29||2017
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD4101C8>)
# 30||2017
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD2BF9C8>)
# 31||2017
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD403EC8>)
# 0||2018
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD66A148>)
# 1||2018
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD40A648>)
# 2||2018
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD402A88>)
# 3||2018
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD2BF9C8>)
# 4||2018
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD6974C8>)
# 5||2018
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD2CC988>)
# 6||2018
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD6802C8>)
# 7||2018
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD40F548>)
# 8||2018
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD2CC988>)
# 9||2018
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD4036C8>)
# 10||2018
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD412088>)
# 11||2018
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD2184C8>)
# 12||2018
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDBB8EF88>)
# 13||2018
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD40A648>)
# 14||2018
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD3D4408>)
# 15||2018
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD3BE688>)
# 16||2018
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD2184C8>)
# 17||2018
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD40F548>)
# 18||2018
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDA1172C8>)
# 19||2018
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD2CC988>)
# 20||2018
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD414EC8>)
# 21||2018
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD686288>)
# 22||2018
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD2BF9C8>)
# 23||2018
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD2184C8>)
# 24||2018
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDCC18A08>)
# 25||2018
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD6869C8>)
# 26||2018
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD405088>)
# 27||2018
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDC023108>)
# 28||2018
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD257F48>)
# 29||2018
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD403D48>)
# 30||2018
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD414848>)
# 31||2018
# (<class 'KeyError'>, KeyError('defense'), <traceback object at 0x0000025FDD257F48>)
# Empty DataFrame
# Columns: [Season, Team ID, TKey, Def Assisted Tackles, Def Blitzes, Def Combined Tackles, Def Defensive Completions, Def Defensive Targets, Def Forced Fumbles, Def Fumble Recoveries, Def Hurries, Def Interceptions, Def Knockdowns, Def Misc Assists, Def Misc Forced Fumbles, Def Misc Fumble Recoveries, Def Misc Tackles, Def Missed Tackles, Def Passes Defended, Def QB Hits, Def Sack Yards, Def Sacks, Def Safeties, Def Special Team Assists, Def Special Team Bocks, Def Special Team Forced Fumbles, Def Special Team Fumble Recoveries, Def Special Team Tackles, Def Tackles, Def Tackles for Loss, Def Tackles for Loss Yards]
# Index: []
#
# [0 rows x 31 columns]

# %%
df.to_csv(r'Resources/Output/Team_Stats_2012_2018_Defense.csv')
